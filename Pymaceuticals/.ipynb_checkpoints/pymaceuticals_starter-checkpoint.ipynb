# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import sem
import csv

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_df=pd.DataFrame(mouse_metadata)
study_df=pd.DataFrame(study_results)
merged_data=pd.merge(left=mouse_df, right=study_df, left_on='Mouse ID', right_on='Mouse ID')
merged_data=merged_data.rename(columns={'Mouse ID': 'mouse_id'})
# Display the data table for preview
# print (mouse_df.head())
# print (study_df.head())
merged_data.head(10)
# Out:
#   mouse_id Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
# 5     k403     Ramicane  Male          21          16         25
# 6     k403     Ramicane  Male          21          16         30
# 7     k403     Ramicane  Male          21          16         35
# 8     k403     Ramicane  Male          21          16         40
# 9     k403     Ramicane  Male          21          16         45
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1
# ...

# %%
# Checking the number of mice.
m_count=merged_data.mouse_id.unique()
print (len(m_count))
print (len(merged_data['Timepoint']))
# Out:
# 249
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
scrubbed_data=merged_data.drop_duplicates(['Timepoint', 'mouse_id'])
m_count_s=scrubbed_data.mouse_id.unique()
print (len(m_count_s))
print (len(scrubbed_data['Timepoint']))
# Out:
# 249
# 1888

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicates = merged_data.loc[merged_data.duplicated(['Timepoint', 'mouse_id']), :]
duplicates
# Out:
#     mouse_id Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
df=pd.DataFrame(scrubbed_data)
df=df.rename(columns={'Tumor Volume (mm3)': 'tumor_volume_mm3'})
df.head(10)
# df.to_excel("output.xlsx")
# Out:
#   mouse_id Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
# 5     k403     Ramicane  Male          21          16         25
# 6     k403     Ramicane  Male          21          16         30
# 7     k403     Ramicane  Male          21          16         35
# 8     k403     Ramicane  Male          21          16         40
# 9     k403     Ramicane  Male          21          16         45
#
#    tumor_volume_mm3  Metastatic Sites
# 0         45.000000                 0
# 1         38.825898                 0
# 2         35.014271                 1
# 3         34.223992                 1
# 4         32.997729                 1
# ...

# %%
# Checking the number of mice in the clean DataFrame.
print (len(df.mouse_id.unique()))
print (len(df['mouse_id']))
# Out:
# 249
# 1888

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# df.describe
# df[["tumor_volume_mm3"]].describe()
avg_tv=df.groupby('Drug Regimen').mean()['tumor_volume_mm3']
median_tv=df.groupby('Drug Regimen').median()['tumor_volume_mm3']
tv_variance=df.groupby('Drug Regimen').var()['tumor_volume_mm3']
tv_std=df.groupby('Drug Regimen').std()['tumor_volume_mm3']
tv_sem=df.groupby('Drug Regimen').sem()['tumor_volume_mm3']
ss_df1= pd.DataFrame({'Avgerage': avg_tv, 'Median': median_tv, 'Variance': tv_variance, 'Standard Deviation': tv_std, 'SEM': tv_sem})
# groupby.agg([sem])
# This method is the most straighforward, creating multiple series and putting them all together at the end
ss_df1
# Out:
#                Avgerage     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803            6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# regimen_summary=df.groupby('Drug Regimen').tumor_volume_mm3.describe()
regimen_summary=df.groupby('Drug Regimen').agg({'tumor_volume_mm3': ['mean', 'median', 'std', 'var', 'sem']})
sales_summary = pd.DataFrame(regimen_summary)
sales_summary=sales_summary.rename(columns={'mean': 'Average', 'median': 'Median', 'std': 'Std dev', 'var': 'Variance', 'sem': 'SEM'})
#                              , columns = ['Average', 'Median', 'Variance', 'Std dev', 'SEM']) 
# .agg 
# avg_weight=df.groupby('Drug Regimen').mean()['tumor_volume_mm3']
#newdf= pd.DataFrame({'Avg': avg_weight, 'Mean': })
# sem=df.sem()
# This method produces everything in a single groupby function
sales_summary
# print (sem.head())
# Out:
#              tumor_volume_mm3
#                       Average     Median   Std dev   Variance       SEM
# Drug Regimen
# Capomulin           40.675741  41.557809  4.994774  24.947764  0.329346
# Ceftamin            52.591172  51.776157  6.268188  39.290177  0.469821
# Infubinol           52.884795  51.820584  6.567243  43.128684  0.492236
# Ketapril            55.235638  53.698743  8.279709  68.553577  0.603860
# Naftisol            54.331565  52.509285  8.134708  66.173479  0.596466
# Placebo             54.033581  52.288934  7.821003  61.168083  0.581331
# Propriva            52.393463  50.909965  6.568014  43.138803  0.525862
# Ramicane            40.216745  40.673236  4.846308  23.486704  0.320955
# Stelasyn            54.233149  52.431737  7.710419  59.450562  0.573111
# Zoniferol           53.236507  51.818479  6.966589  48.533355  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
treatment_group = df.groupby('Drug Regimen')
# Count how many times each mouse appears in that group
count_mice = treatment_group['mouse_id'].count()
# count() matches closer 
panda_plot=count_mice.plot.bar(figsize=(10, 5),)
panda_plot
# print (count_mice)

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
# treatment_chart = count_mice.plot(kind='bar')
# bar_plot_df=df.groupby('Drug Regimen').mouse_id.count().unstack().plot.bar()
# x_axis=[Capomulin,'Ceftamin', 'Infubinol', ]
# plt.bar(x_axis, count_mice, color="b", align="center")
# # # plt.plot(['Drug Regimen'], 'count_mice')
# plt.show()
# go back to matplotlib activity use .plt
# bar_plot_df
# print (treatment_group)
dr_bar = df.groupby('Drug Regimen')['mouse_id'].count()

ax = dr_bar.plot(kind='bar', figsize=(10,6), color="indigo", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("My Bar Plot", fontsize=22)
ax.set_ylabel("Some Heading on Y-Axis", fontsize=15);
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_group = df.groupby('Sex')['mouse_id'].nunique()
pandapie =gender_group.plot.pie(subplots=True, figsize=(10, 5),)
pandapie
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4B4430588>],
#       dtype=object)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
Sex=['Female', 'Male']
colors=["lightcoral", "lightskyblue"]
plt.pie(gender_group, labels=Sex, colors=colors, autopct="%1.1f%%",)
plt.title("Female/Male Distribution")
# gender_group
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# condition = df.groupby(mouse_id)["Timepoint"]
filtered_df = df.groupby(['Drug Regimen', 'mouse_id']).last()['tumor_volume_mm3']
tumor_df=pd.DataFrame(filtered_df).reset_index()
tumor_df=tumor_df.rename(columns={'Drug Regimen': 'Drug_Regimen'})
regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
regimen_df = tumor_df[tumor_df['Drug_Regimen'].isin(regimens)]
# merge_df = pd.merge(tumor_df, df, on="mouse_id", how='left')
# need to get new series and merger to new DF
# print (filtered_df)
# filtered_df
regimen_df=pd.DataFrame(regimen_df)
regimen_df
# regimen_df
# merge_df
# meds= [Capomulin, Ramicane, Infubinol, Ceftamin]
# best_regimes = merge_data[merge_data["Drug Regimen"].isin(["Capomulin", "Ramicane", "Infubinol", "Ceftamin"])]
# best_regimes = best_regimes.sort_values(["Timepoint"], ascending=True)
# best_regimes

# best_regimes_data = best_regimes[["Drug Regimen", "Mouse ID", "Timepoint", "Tumor Volume (mm3)"]]

# best_regimes_data


# Start by getting the last (greatest) timepoint for each mouse
# final_volume=df.groupby(['Drug Regimen'])['Timepoint'].idxmax()
# # print (final_volume)

# final_volume=df.groupby('Drug Regimen').Timepoint.max()
# # final_volume=df.groupby('Drug Regimen').size().reset_index(Timepoint='max')
# # Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# # final_volume_df=df.loc[df.reset_index().groupby(['Drug Regimen'])['tumor_volume_mm3'].idxmax()]
# # # final_volume_df=pd.DataFrame(final_volume)
# final_volume_df=pd.DataFrame(final_volume)
# final_volume_df
# Out:
#     Drug_Regimen mouse_id  tumor_volume_mm3
# 0      Capomulin     b128         38.982878
# 1      Capomulin     b742         38.939633
# 2      Capomulin     f966         30.485985
# 3      Capomulin     g288         37.074024
# 4      Capomulin     g316         40.159220
# ..           ...      ...               ...
# 195     Ramicane     s508         30.276232
# 196     Ramicane     u196         40.667713
# 197     Ramicane     w678         43.166373
# 198     Ramicane     y449         44.183451
# 199     Ramicane     z578         30.638696
#
# [100 rows x 3 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data=[]

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
tumor_volumes = regimen_df['tumor_volume_mm3']
q1 = regimen_df['tumor_volume_mm3'].quantile(.25)
q3 = regimen_df['tumor_volume_mm3'].quantile(.75)
iqr = q3 - q1

regimen_df
fig1, ax1 = plt.subplots()
ax1.set_title('Final tumor volume')
ax1.set_ylabel('tumor_volume_mm3')
ax1.boxplot(tumor_volumes)
plt.show()
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
subsets = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
print(iqr)
# Out:
# 22.74251795250001

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
final_df = regimen_df.reset_index()
reg_plot = final_df.groupby('Drug_Regimen')['tumor_volume_mm3'].apply(list)
reg_plot_df = pd.DataFrame(reg_plot)
reg_plot_df = reg_plot_df.reindex(subsets)
tumor_vols = [vol for vol in reg_plot_df['tumor_volume_mm3']]
plt.boxplot(tumor_vols, labels=subsets)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
plots_df = df.loc[df["Drug Regimen"] == "Capomulin",:]
s185_df = plots_df.loc[plots_df["mouse_id"] == "s185",:]
# filtered_df
# plots_df
s185_df
# final_df
xaxis = s185_df["Timepoint"]
yaxis = s185_df["tumor_volume_mm3"]


plt.plot(xaxis, yaxis,linewidth=1, markersize=10)
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Capomulin treatmeant Mouse s185')

plt.savefig('linechart')
plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
avg = plots_df.groupby(['mouse_id']).mean()
plt.scatter(avg['Weight (g)'],avg['tumor_volume_mm3'])
plt.xlabel('Weight')
plt.ylabel('Average Tumor Volume (mm3)')

plt.savefig('scatterplot')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
